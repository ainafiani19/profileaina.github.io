# %%
import requests
import json
import os

# %%
#link API Rumah Sakit
urls ={
    "RS_JakBar":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fafc44612b4d22f2e1ee&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RS_JakPus":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fafd7b6af506bf464b2e&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RS_JakSel":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fafe44612b4d22f2ead2&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RS_JakTim":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4faff7b6af506bf465786&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RS_JakUt":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb0144612b4d22f2f7b6&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RS_KabBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb0d44612b4d22f30202&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RS_KotBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb0e7b6af506bf465b55&project_id=68f488c244612b4d22ec2f83&limit=10000",

}

for nama, url in urls.items():
    response = requests.get(url)
    data = response.json()

    filename = f"{nama}.geojson"
    with open(filename,"w",encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    print(f"✅ {filename} berhasil disimpan")
    print(os.getcwd())
# Out:
# ✅ RS_JakBar.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RS_JakPus.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RS_JakSel.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RS_JakTim.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RS_JakUt.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RS_KabBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RS_KotBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project

# %%
#link API Klinik dan Apotek
urls ={
    "RSG_JakBar":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb3644612b4d22f3281f&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RSG_JakPus":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb3b44612b4d22f3349c&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RSG_JakSel":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb4144612b4d22f33d44&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RSG_JakTim":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb447b6af506bf466847&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RSG_JakUt":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb4f44612b4d22f3533a&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RSG_KabBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb1744612b4d22f3159e&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "RSG_KotBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb187b6af506bf46602f&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "klinik_JakBar":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb6c44612b4d22f37218&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "klinik_JakPus":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb7744612b4d22f39465&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "klinik_JakSel":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fb7144612b4d22f382e2&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Apotek_KabBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fc437b6af506bf466e07&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Apotek_KotBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fc4544612b4d22f3a57e&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Apotek_JakBar":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fc527b6af506bf467bbe&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Apotek_JakPus":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fc5f7b6af506bf468e2b&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Apotek_JakSel":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fc5f7b6af506bf469089&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Apotek_JakTim":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fc627b6af506bf469915&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Apotek_JakUt":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fc627b6af506bf469ced&project_id=68f488c244612b4d22ec2f83&limit=10000",
}

for nama, url in urls.items():
    response = requests.get(url)
    data = response.json()

    filename = f"{nama}.geojson"
    with open(filename,"w",encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    print(f"✅ {filename} berhasil disimpan")
    print(os.getcwd())
# Out:
# ✅ RSG_JakBar.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RSG_JakPus.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RSG_JakSel.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RSG_JakTim.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RSG_JakUt.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RSG_KabBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ RSG_KotBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ klinik_JakBar.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ klinik_JakPus.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ klinik_JakSel.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Apotek_KabBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Apotek_KotBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Apotek_JakBar.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ...

# %%
#link API Pendidikan

urls ={
    "Pendidikan_KabBekasi":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fcc57b6af506bf46c2eb&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Pendidikan_KotBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fcc644612b4d22f3ea9a&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Pendidikan_JakBar":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fea644612b4d22f41f7d&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Pendidikan_JakPus":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fea67b6af506bf46f219&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Pendidikan_JakSel":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fea744612b4d22f42031&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Pendidikan_JakTim":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fea87b6af506bf46f551&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Pendidikan_JakUt":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4fea944612b4d22f42ac3&project_id=68f488c244612b4d22ec2f83&limit=10000",
    
}

for nama, url in urls.items():
    response = requests.get(url)
    data = response.json()

    filename = f"{nama}.geojson"
    with open(filename,"w",encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    print(f"✅ {filename} berhasil disimpan")
    print(os.getcwd())
# Out:
# ✅ Pendidikan_KabBekasi.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Pendidikan_KotBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Pendidikan_JakBar.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Pendidikan_JakPus.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Pendidikan_JakSel.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Pendidikan_JakTim.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Pendidikan_JakUt.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project

# %%
#link API Transportasi
urls={
    "PintuTol_KabBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4ff157b6af506bf4731fa&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "PintuTol_KotBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4ff957b6af506bf47766a&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "PintuTol_JakBar":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4ffae7b6af506bf478adf&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "PintuTol_JakPus":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4ffb044612b4d22f4a103&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "PintuTol_JakSel":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4ffb57b6af506bf47ad55&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "PintuTol_JakTim":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4ffbb7b6af506bf47c9cb&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "PintuTol_JakUt":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4ffc27b6af506bf47e6ca&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Stasiun_KabBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f500087b6af506bf4822c4&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Stasiun_KotBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f5000944612b4d22f4a8c8&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Stasiun_JakBar":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f5002244612b4d22f4bfae&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Stasiun_JakPus":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f5002d44612b4d22f4de81&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Stasiun_JakSel":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f5003744612b4d22f4fdd8&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Stasiun_JakTim":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f5004744612b4d22f51daa&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "Stasiun_JakUt":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f5005c44612b4d22f53de3&project_id=68f488c244612b4d22ec2f83&limit=10000",

}

for nama, url in urls.items():
    response = requests.get(url)
    data = response.json()

    filename = f"{nama}.geojson"
    with open(filename,"w",encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    print(f"✅ {filename} berhasil disimpan")
    print(os.getcwd())
# Out:
# ✅ PintuTol_KabBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ PintuTol_KotBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ PintuTol_JakBar.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ PintuTol_JakPus.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ PintuTol_JakSel.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ PintuTol_JakTim.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ PintuTol_JakUt.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Stasiun_KabBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Stasiun_KotBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Stasiun_JakBar.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Stasiun_JakPus.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Stasiun_JakSel.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Stasiun_JakTim.geojson berhasil disimpan
# ...

# %%
#link API Banjir

urls={
  "Banjir_KotBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f5021444612b4d22f5fb51&project_id=68f488c244612b4d22ec2f83&limit=10000",
  "Banjir_KabBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f5021d7b6af506bf490ca8&project_id=68f488c244612b4d22ec2f83&limit=10000",
  "Banjir_JakUt":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f502f47b6af506bf49a4a4&project_id=68f488c244612b4d22ec2f83&limit=10000",
  "Banjir_JakTim":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f503007b6af506bf49cb1b&project_id=68f488c244612b4d22ec2f83&limit=10000",
  "Banjir_JakSel":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f5030a7b6af506bf49f296&project_id=68f488c244612b4d22ec2f83&limit=10000",
  "Banjir_JakPus":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f503177b6af506bf4a19e7&project_id=68f488c244612b4d22ec2f83&limit=10000",
  "Banjir_JakBar":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f503db7b6af506bf4a4060&project_id=68f488c244612b4d22ec2f83&limit=10000",  
}

for nama, url in urls.items():
    response = requests.get(url)
    data = response.json()

    filename = f"{nama}.geojson"
    with open(filename,"w",encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    print(f"✅ {filename} berhasil disimpan")
    print(os.getcwd())
# Out:
# ✅ Banjir_KotBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Banjir_KabBek.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Banjir_JakUt.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Banjir_JakTim.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Banjir_JakSel.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Banjir_JakPus.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
# ✅ Banjir_JakBar.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project

# %%
#link API Harga Properti

urls={
    #"HargaProperti_KotBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f48bd444612b4d22ec4a0b&project_id=68f488c244612b4d22ec2f83&limit=10000",
    #"HargaProperti_KabBek":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f48cd944612b4d22ec5c6a&project_id=68f488c244612b4d22ec2f83&limit=10000",
    #"HargaProperti_JakBar":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4daed44612b4d22ee4f89&project_id=68f488c244612b4d22ec2f83&limit=10000",
    #"HargaProperti_JakTim":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4daf07b6af506bf42b389&project_id=68f488c244612b4d22ec2f83&limit=10000",
    "HargaProperti_JakPus":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4daee7b6af506bf42ad65&project_id=68f488c244612b4d22ec2f838&limit=10000",
    #"HargaProperti_Jaksel":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4daef44612b4d22ee503b&project_id=68f488c244612b4d22ec2f83&limit=10000",
    #"HargaProperti_JakUt":"https://geoserver.mapid.io/layers_new/get_layer?api_key=5249521c14de436ebcf1fb8f05e6048d&layer_id=68f4daf144612b4d22ee5830&project_id=68f488c244612b4d22ec2f83&limit=10000",
}

for nama, url in urls.items():
    response = requests.get(url)
    data = response.json()

    filename = f"{nama}.geojson"
    with open(filename,"w",encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

    print(f"✅ {filename} berhasil disimpan")
    print(os.getcwd())
# Out:
# ✅ HargaProperti_JakPus.geojson berhasil disimpan
# d:\BOOTCAMP MAPID\Final Project
